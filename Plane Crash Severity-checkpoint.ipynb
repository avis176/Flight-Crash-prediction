# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
train=pd.read_csv("C:/Users/abhishek/Desktop/Dataset for practice/Plane Crash Severity/train.csv")

# %%
train.head(10)
# Out:
#                                   Severity  Safety_Score  \
# 0                Minor_Damage_And_Injuries     49.223744
# 1                Minor_Damage_And_Injuries     62.465753
# 2        Significant_Damage_And_Fatalities     63.059361
# 3  Significant_Damage_And_Serious_Injuries     48.082192
# 4        Significant_Damage_And_Fatalities     26.484018
# 5                Minor_Damage_And_Injuries     43.333333
# 6                Highly_Fatal_And_Damaging     22.009132
# 7                Minor_Damage_And_Injuries     24.703196
# 8                Highly_Fatal_And_Damaging     54.840183
# 9  Significant_Damage_And_Serious_Injuries     52.237443
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0                     14                       22       71.285324
# 1                     10                       27       72.288058
# 2                     13                       16       66.362808
# 3                     11                        9       74.703737
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
# Severity                   10000 non-null object
# Safety_Score               10000 non-null float64
# Days_Since_Inspection      10000 non-null int64
# Total_Safety_Complaints    10000 non-null int64
# Control_Metric             10000 non-null float64
# Turbulence_In_gforces      10000 non-null float64
# Cabin_Temperature          10000 non-null float64
# Accident_Type_Code         10000 non-null int64
# Max_Elevation              10000 non-null float64
# Violations                 10000 non-null int64
# Adverse_Weather_Metric     10000 non-null float64
# Accident_ID                10000 non-null int64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 937.6+ KB

# %%
train.shape
# Out:
# (10000, 12)

# %%
train.describe()
# Out:
#        Safety_Score  Days_Since_Inspection  Total_Safety_Complaints  \
# count  10000.000000           10000.000000             10000.000000
# mean      41.876406              12.931100                 6.564300
# std       16.138072               3.539803                 6.971982
# min        0.000000               1.000000                 0.000000
# 25%       30.593607              11.000000                 2.000000
# 50%       41.278539              13.000000                 4.000000
# 75%       52.511416              15.000000                 9.000000
# max      100.000000              23.000000                54.000000
#
#        Control_Metric  Turbulence_In_gforces  Cabin_Temperature  \
# count    10000.000000           10000.000000       10000.000000
# mean        65.145324               0.381495          79.969331
# std         11.882934               0.121301           2.759739
# min          0.000000               0.134000          74.740000
# ...

# %%
train.isnull().sum()
# Out:
# Severity                   0
# Safety_Score               0
# Days_Since_Inspection      0
# Total_Safety_Complaints    0
# Control_Metric             0
# Turbulence_In_gforces      0
# Cabin_Temperature          0
# Accident_Type_Code         0
# Max_Elevation              0
# Violations                 0
# Adverse_Weather_Metric     0
# Accident_ID                0
# dtype: int64

# %%
test=pd.read_csv("C:/Users/abhishek/Desktop/Dataset for practice/Plane Crash Severity/test.csv")

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 11 columns):
# Safety_Score               2500 non-null float64
# Days_Since_Inspection      2500 non-null int64
# Total_Safety_Complaints    2500 non-null int64
# Control_Metric             2500 non-null float64
# Turbulence_In_gforces      2500 non-null float64
# Cabin_Temperature          2500 non-null float64
# Accident_Type_Code         2500 non-null int64
# Max_Elevation              2500 non-null float64
# Violations                 2500 non-null int64
# Adverse_Weather_Metric     2500 non-null float64
# Accident_ID                2500 non-null int64
# dtypes: float64(6), int64(5)
# memory usage: 214.9 KB

# %%
test.isnull().sum()
# Out:
# Safety_Score               0
# Days_Since_Inspection      0
# Total_Safety_Complaints    0
# Control_Metric             0
# Turbulence_In_gforces      0
# Cabin_Temperature          0
# Accident_Type_Code         0
# Max_Elevation              0
# Violations                 0
# Adverse_Weather_Metric     0
# Accident_ID                0
# dtype: int64

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="Severity", data=train)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %%
train["Accident_Type_Code"]=train["Accident_Type_Code"].astype(object)
train["Violations"]=train["Violations"].astype(object)

# %%
train.dtypes
# Out:
# Severity                    object
# Safety_Score               float64
# Days_Since_Inspection        int64
# Total_Safety_Complaints      int64
# Control_Metric             float64
# Turbulence_In_gforces      float64
# Cabin_Temperature          float64
# Accident_Type_Code          object
# Max_Elevation              float64
# Violations                  object
# Adverse_Weather_Metric     float64
# Accident_ID                  int64
# dtype: object

# %%
#univariate analysis of Numerical variables:
numerical=[feature for feature in train.columns if train[feature].dtypes !='object' and feature not in 'Accident_ID']

# %%
len(numerical)
# Out:
# 8

# %%
for feature in numerical:
    data=train.copy()
    data[feature].hist(bins=15)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
train.columns
# Out:
# Index(['Severity', 'Safety_Score', 'Days_Since_Inspection',
#        'Total_Safety_Complaints', 'Control_Metric', 'Turbulence_In_gforces',
#        'Cabin_Temperature', 'Accident_Type_Code', 'Max_Elevation',
#        'Violations', 'Adverse_Weather_Metric', 'Accident_ID'],
#       dtype='object')

# %%
train['Violations'].nunique()
# Out:
# 6

# %%
train['Violations'].unique()
# Out:
# array([3, 2, 1, 0, 4, 5], dtype=object)

# %%
#Skewness of numerical 
from scipy.stats import skew
skewed = train[numerical].apply(lambda x: skew(x.dropna().astype(float)))

# %%
print(skewed)
# Out:
# Safety_Score               0.236266
# Days_Since_Inspection     -0.073899
# Total_Safety_Complaints    1.887797
# Control_Metric            -0.201452
# Turbulence_In_gforces      0.816624
# Cabin_Temperature          0.854309
# Max_Elevation             -0.038189
# Adverse_Weather_Metric     2.073775
# dtype: float64

# %%
numeric=['Total_Safety_Complaints','Control_Metric','Turbulence_In_gforces','Cabin_Temperature','Adverse_Weather_Metric']

# %%
#logarthimic transformation for Skewed numeric variables:
for feature in train[numeric]:
    data=train.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data[feature].hist()
        plt.xlabel(feature)
        plt.ylabel("Count")
        plt.title(feature)
        plt.show()

# %%
categorical= [feature for feature in train.columns if train[feature].dtypes =='object']

# %%
len(categorical)
# Out:
# 3

# %%
#No. of unique values in a categorical:
train[categorical].nunique().sort_values(ascending=False)
# Out:
# Accident_Type_Code    7
# Violations            6
# Severity              4
# dtype: int64

# %%
for feature in categorical:
    data=train.copy()
    ax = sns.countplot(x=feature, data=train)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.xticks(rotation=90)
    plt.show()

# %%
#Bi-variate analysis for categorical and categorical variable:
sns.set(style="darkgrid")
ax = sns.countplot(x="Severity", hue="Violations", data=train)
plt.xticks(rotation=90)
plt.show()

# %%
ax = sns.countplot(x="Severity", hue="Accident_Type_Code",data=train)
plt.xticks(rotation=90)
plt.show()

# %%
for feature in numerical:
    data=train.copy
    g = sns.FacetGrid(train, col='Severity')
    g.map(plt.hist,feature,bins=15)

# %%
train.columns
# Out:
# Index(['Severity', 'Safety_Score', 'Days_Since_Inspection',
#        'Total_Safety_Complaints', 'Control_Metric', 'Turbulence_In_gforces',
#        'Cabin_Temperature', 'Accident_Type_Code', 'Max_Elevation',
#        'Violations', 'Adverse_Weather_Metric', 'Accident_ID'],
#       dtype='object')

# %%
#featue scaling
feature_scale=[feature for feature in train.columns if feature not in ['Severity','Accident_Type_Code','Violations','Accident_ID']]

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(train[feature_scale])
# Out:
# C:\Users\abhishek\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
train_new=pd.concat([train[['Severity','Accident_Type_Code','Violations','Accident_ID']].reset_index(drop=True),
                   pd.DataFrame(scaler.transform(train[feature_scale]),columns=feature_scale)],
                    axis=1)

# %%
train_new.head()
# Out:
#                                   Severity Accident_Type_Code Violations  \
# 0                Minor_Damage_And_Injuries                  2          3
# 1                Minor_Damage_And_Injuries                  2          2
# 2        Significant_Damage_And_Fatalities                  7          3
# 3  Significant_Damage_And_Serious_Injuries                  3          1
# 4        Significant_Damage_And_Fatalities                  3          2
#
#    Accident_ID  Safety_Score  Days_Since_Inspection  Total_Safety_Complaints  \
# 0         7570      0.492237               0.590909                 0.407407
# 1        12128      0.624658               0.409091                 0.500000
# 2         2181      0.630594               0.545455                 0.296296
# 3         5946      0.480822               0.454545                 0.166667
# 4         9054      0.264840               0.545455                 0.462963
#
# ...

# %%
train_new.shape
# Out:
# (10000, 12)

# %%
train_new.columns
# Out:
# Index(['Severity', 'Accident_Type_Code', 'Violations', 'Accident_ID',
#        'Safety_Score', 'Days_Since_Inspection', 'Total_Safety_Complaints',
#        'Control_Metric', 'Turbulence_In_gforces', 'Cabin_Temperature',
#        'Max_Elevation', 'Adverse_Weather_Metric'],
#       dtype='object')

# %%
#dummy variable
X_train=pd.get_dummies(train_new,columns=['Accident_Type_Code','Violations'],drop_first=True)

# %%
X_train.shape
# Out:
# (10000, 21)

# %%
X_train.head()
# Out:
#                                   Severity  Accident_ID  Safety_Score  \
# 0                Minor_Damage_And_Injuries         7570      0.492237
# 1                Minor_Damage_And_Injuries        12128      0.624658
# 2        Significant_Damage_And_Fatalities         2181      0.630594
# 3  Significant_Damage_And_Serious_Injuries         5946      0.480822
# 4        Significant_Damage_And_Fatalities         9054      0.264840
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0               0.590909                 0.407407        0.712853
# 1               0.409091                 0.500000        0.722881
# 2               0.545455                 0.296296        0.663628
# 3               0.454545                 0.166667        0.747037
# 4               0.545455                 0.462963        0.479490
#
#    Turbulence_In_gforces  Cabin_Temperature  Max_Elevation  \
# 0               0.184489           0.144928       0.480632
# ...

# %%
#Y_train = train_df1["Loan_Status"].map({'Y':1,'N':0})

# %%
test["Accident_Type_Code"]=test["Accident_Type_Code"].astype(object)
test["Violations"]=test["Violations"].astype(object)

# %%
numeric=[feature for feature in test.columns if test[feature].dtypes !='object' and feature not in 'Accident_ID']

# %%
len(numeric)
# Out:
# 8

# %%
#featue scaling for test data
feature_scale_test=[feature for feature in test.columns if feature not in ['Accident_Type_Code','Violations','Accident_ID']]

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(test[feature_scale_test])
# Out:
# C:\Users\abhishek\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
test_new=pd.concat([test[['Accident_Type_Code','Violations','Accident_ID']].reset_index(drop=True),
                   pd.DataFrame(scaler.transform(test[feature_scale_test]),columns=feature_scale_test)],
                    axis=1)

# %%
test_new.head()
# Out:
#   Accident_Type_Code Violations  Accident_ID  Safety_Score  \
# 0                  4          2            1      0.194977
# 1                  7          2           10      0.581735
# 2                  6          1           14      0.332877
# 3                  3          2           17      0.032877
# 4                  2          2           21      0.108676
#
#    Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# 0               0.681818                 0.111111        0.664497
# 1               0.636364                 0.055556        0.566272
# 2               0.636364                 0.055556        0.568047
# 3               0.909091                 0.092593        0.589349
# 4               0.772727                 0.037037        0.456213
#
#    Turbulence_In_gforces  Cabin_Temperature  Max_Elevation  \
# 0               0.332520           0.183967       0.603705
# 1               0.145508           0.198356       0.477575
# ...

# %%
X_test=pd.get_dummies(test_new,columns=['Accident_Type_Code','Violations'],drop_first=True)

# %%
X_test.shape
# Out:
# (2500, 20)

# %%
X_train.to_csv("train_modified.csv",index=False)
X_test.to_csv("test_modified.csv",index=False)

# %%
train_df=pd.read_csv("C:/Users/abhishek/Desktop/Dataset for practice/Plane Crash Severity/train_modified.csv")
test_df=pd.read_csv("C:/Users/abhishek/Desktop/Dataset for practice/Plane Crash Severity/test_modified.csv")

# %%
train_df.shape
# Out:
# (10000, 21)

# %%
train_df.columns
# Out:
# Index(['Severity', 'Accident_ID', 'Safety_Score', 'Days_Since_Inspection',
#        'Total_Safety_Complaints', 'Control_Metric', 'Turbulence_In_gforces',
#        'Cabin_Temperature', 'Max_Elevation', 'Adverse_Weather_Metric',
#        'Accident_Type_Code_2', 'Accident_Type_Code_3', 'Accident_Type_Code_4',
#        'Accident_Type_Code_5', 'Accident_Type_Code_6', 'Accident_Type_Code_7',
#        'Violations_1', 'Violations_2', 'Violations_3', 'Violations_4',
#        'Violations_5'],
#       dtype='object')

# %%
train_df['Severity'].unique()
# Out:
# array(['Minor_Damage_And_Injuries', 'Significant_Damage_And_Fatalities',
#        'Significant_Damage_And_Serious_Injuries',
#        'Highly_Fatal_And_Damaging'], dtype=object)

# %%
holdout=test_df

# %%
holdout.shape
# Out:
# (2500, 20)

# %%
from sklearn.model_selection import train_test_split

all_X = train_df.drop(['Severity'],axis=1)
all_y = train_df['Severity'].map({'Minor_Damage_And_Injuries':0,'Significant_Damage_And_Fatalities':1,
                                'Significant_Damage_And_Serious_Injuries':2,'Highly_Fatal_And_Damaging':3 })

train_X, test_X, train_y, test_y = train_test_split(all_X, all_y, test_size=0.20,random_state=0)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# #clf = KNeighborsClassifier(n_neighbors = 13)
# #scoring = 'f1_weighted'
# #score = cross_val_score(clf,train_X ,train_y, cv=k_fold, n_jobs=1, scoring=scoring)
# #print(score)
# #print(score.mean())

# %%
clf = DecisionTreeClassifier()
scoring = 'f1_weighted'
score = cross_val_score(clf,train_X ,train_y, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
print(score.mean())
# Out:
# [0.90423869 0.90863568 0.91007527 0.90991021 0.90457276]
# 0.9074865200207787

# %% [markdown]
# #clf = RandomForestClassifier(n_estimators=100)
# #scoring = 'f1_weighted'
# #score = cross_val_score(clf,train_X ,train_y, cv=k_fold, n_jobs=1, scoring=scoring)
# #print(score)
# #print(score.mean())

# %%
clf.fit(train_X ,train_y)
Y_predict=clf.predict(holdout)
Y_predict
# Out:
# array([3, 2, 0, ..., 2, 2, 1], dtype=int64)

# %%
holdout_ids = holdout["Accident_ID"]
submission_df = pd.DataFrame({"Accident_ID": holdout_ids,
                 "Severity":Y_predict})

# %%
submission_df['Severity'] = submission_df['Severity'].map({0:'Minor_Damage_And_Injuries',1:'Significant_Damage_And_Fatalities',
                                                           2:'Significant_Damage_And_Serious_Injuries',3:'Highly_Fatal_And_Damaging'})

# %%
submission_df.head()
# Out:
#    Accident_ID                                 Severity
# 0            1                Highly_Fatal_And_Damaging
# 1           10  Significant_Damage_And_Serious_Injuries
# 2           14                Minor_Damage_And_Injuries
# 3           17                Highly_Fatal_And_Damaging
# 4           21                Highly_Fatal_And_Damaging

# %%
submission_df.to_csv('C:/Users/abhishek/Desktop/Dataset for practice/Plane Crash Severity/plane_crash_new.csv', index=False)
